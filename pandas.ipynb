# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.__version__
# Out:
# '1.3.5'

# %%
dict_data = {'Partidos':[100,220,300,200],'Goles':[300,343,232,323],'Goles_contra':[342,453,234,243]}
dict_data
# Out:
# {'Goles': [300, 343, 232, 323],
#  'Goles_contra': [342, 453, 234, 243],
#  'Partidos': [100, 220, 300, 200]}

# %%
tabla_goles = pd.DataFrame(dict_data,index= ['COL','MX','ARG','BRA'])
tabla_goles
# Out:
#      Partidos  Goles  Goles_contra
# COL       100    300           342
# MX        220    343           453
# ARG       300    232           234
# BRA       200    323           243

# %%
#Total partidos y goles 
tabla_goles.groupby('Partidos').Goles.sum()
# Out:
# Partidos
# 100    300
# 200    323
# 220    343
# 300    232
# Name: Goles, dtype: int64

# %%
#Goles a favor y en contra
tabla_goles.iloc[:,[1,2]]
# Out:
#      Goles  Goles_contra
# COL    300           342
# MX     343           453
# ARG    232           234
# BRA    323           243

# %%
#equipos con goles mayores a 300
tabla_goles[tabla_goles['Goles']>300]
# Out:
#      Partidos  Goles  Goles_contra
# MX        220    343           453
# BRA       200    323           243

# %%
#Goles de jugadores
scores= {'jugador':['FORLAN','TEO','FALCAO','CIRSTIANO','MESSI','AGUERO','HIGUAIN','CAVANI','IBRAHIMOBIV','YAYA','RAUL','TOURE','BENZEMA'],
         'partidos':[34,5,3,43,4,3,4,5,65,4,4,5,6],
         'goles': [34,5,6,75,7,5,4,87,5,7,8,4,6],
         'Remates':[54,5,65,4,3,4,5,4,6,6,7,8,9]
         }
scores

# %%
score= pd.DataFrame(scores)
score
# Out:
#         jugador  partidos  goles  Remates
# 0        FORLAN        34     34       54
# 1           TEO         5      5        5
# 2        FALCAO         3      6       65
# 3     CIRSTIANO        43     75        4
# 4         MESSI         4      7        3
# 5        AGUERO         3      5        4
# 6       HIGUAIN         4      4        5
# 7        CAVANI         5     87        4
# 8   IBRAHIMOBIV        65      5        6
# 9          YAYA         4      7        6
# 10         RAUL         4      8        7
# 11        TOURE         5      4        8
# 12      BENZEMA         6      6        9

# %%
#Partidos por jugadores
players.filter(regex='partidos')
# Out:
#              partidos
# FORLAN             34
# TEO                 5
# FALCAO              3
# CIRSTIANO          43
# MESSI               4
# AGUERO              3
# HIGUAIN             4
# CAVANI              5
# IBRAHIMOBIV        65
# YAYA                4
# RAUL                4
# TOURE               5
# BENZEMA             6

# %%
plt.plot(['jugador'],['Remates'],label='Remates')
plt.plot()

plt.xlabel("Jugadores")
plt.ylabel("Remates")
plt.title("Cantidad de remates por partido")
plt.legend()
plt.show()
